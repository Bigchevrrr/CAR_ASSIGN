# %%
#pip install seaborn

# %%
 #pip install --upgrade pip

# %%
#import dependencies


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = pd.read_csv('Iris - Iris.csv')

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data = iris)
plt.title('A plot of SepalLengthCm and SepalWidthCm')
# Out:
# Text(0.5, 1.0, 'A plot of SepalLengthCm and SepalWidthCm')

# %%
#HUE
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue = 'Species', data = iris)
plt.title('A plot of SepalLengthCm and SepalWidthCm')
# Out:
# Text(0.5, 1.0, 'A plot of SepalLengthCm and SepalWidthCm')

# %%
#SCATTER PLOT WITH REGRESSION FIT

sns.regplot(x='SepalLengthCm', y='SepalWidthCm', data = iris)
plt.title('A plot of SepalLengthCm and SepalWidthCm')
# Out:
# Text(0.5, 1.0, 'A plot of SepalLengthCm and SepalWidthCm')

# %%
#CHANGE MAKERS; USE ANOTHER MARKER INSTEAD OF ZERO


sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', data = iris)
plt.title('A plot of SepalLengthCm and SepalWidthCm')
# Out:
# Text(0.5, 1.0, 'A plot of SepalLengthCm and SepalWidthCm')

# %% [markdown]
# # SCATTER PLOT

# %%
sns.lineplot(x='SepalLengthCm', y='SepalWidthCm', data = iris)
plt.title('A plot of SepalLengthCm and SepalWidthCm')
# Out:
# Text(0.5, 1.0, 'A plot of SepalLengthCm and SepalWidthCm')

# %%
#change colour

sns.lineplot(x='SepalLengthCm', y='SepalWidthCm', hue = 'Species', data = iris)
plt.title('A plot of SepalLengthCm and SepalWidthCm')
# Out:
# Text(0.5, 1.0, 'A plot of SepalLengthCm and SepalWidthCm')

# %% [markdown]
# # BAR PLOT

# %%
sns.barplot(x='Species', y='SepalWidthCm', data = iris)
plt.title('A plot of SepalLengthCm and SepalWidthCm')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.barplot(x='Species', y='SepalWidthCm', data = iris)
#       2 plt.title('A plot of SepalLengthCm and SepalWidthCm')
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # CHANGING THE ORIENTATION OF THE BARPLOT

# %%
sns.barplot(y='Species', x='SepalWidthCm', data = iris, orient = 'h')
plt.title('A plot of SepalLengthCm and SepalWidthCm')
# Out:
# Text(0.5, 1.0, 'A plot of SepalLengthCm and SepalWidthCm')

# %% [markdown]
# # SUBPLOT

# %%
#CREATE A FACETGRID FOR SUBPLOTS
g = sns.FacetGrid(iris, col = "Species")

#Map a lineplot to facetgrid
g.map(sns.lineplot, "SepalWidthCm", "PetalLengthCm", marker = "o")

#ADD TITLES TO THE SUBLOTS
g.set_titles(col_template="{col_name} Species")

#ADJUST LAYOUTS
plt.tight_layout()

#SHOW THE SUBPLOTS
plt.show()
# Out:
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\AppData\Local\Temp\ipykernel_5200\57982119.py:11: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
