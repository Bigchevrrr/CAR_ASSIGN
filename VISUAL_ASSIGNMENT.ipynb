# %%
#import numpy as np

# %%
#pip install --upgrade pip

# %%
#import dependencies


import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cloths - cloths.csv')

# %%
df
# Out:
#      Receipt no   Location Customer name  Session id   Sale date   Status  \
# 0          BL11    Chennai          Naga          28  06/03/2020  Ordered
# 1          BL11    Chennai        Mahesh          28  06/03/2020  Ordered
# 2          BL12  Hyderabad        Ganesh          28  06/03/2020  Ordered
# 3          BL12    Chennai         Kumar          28  06/03/2020  Ordered
# 4          BL12  Bangalore         Vijay          28  06/03/2020  Ordered
# ...         ...        ...           ...         ...         ...      ...
# 4967      BL110  Hyderabad          Naga          28  10/07/2020  Ordered
# 4968      BL110    Chennai         Rajiv          28  10/07/2020  Ordered
# 4969      BL108  Bangalore        Mahesh          28  10/07/2020  Ordered
# 4970      BL108    Chennai          Naga          28  10/07/2020  Ordered
# 4971      BL109  Hyderabad        Mahesh          28  10/07/2020  Ordered
#
#      Ordertype name  Token number  Product name Product Category  \
# ...

# %% [markdown]
# # PRODUCT CATEGORY VERSUS COST PER UNIT

# %%
sns.barplot(y='Product Category', x='Cost Per Unit', data = df)
plt.title('A Product Category and Cost Per Unit')
# Out:
# Text(0.5, 1.0, 'A Product Category and Cost Per Unit')

# %% [markdown]
# # QUANTITY VERSUS COST PER UNIT

# %%
sns.lineplot(x='Cost Per Unit', y='Quantity', data = df)
plt.title('Quantity and Cost Per Unit')
# Out:
# Text(0.5, 1.0, 'Quantity and Cost Per Unit')

# %% [markdown]
# # SELLPER UNIT VERSUS COST PER UNIT

# %%
sns.scatterplot(x='Cost Per Unit', y='Selling Per Unit', data = df)
plt.title('A plot of Selling Per Unit and Cost Per Unit')
# Out:
# Text(0.5, 1.0, 'A plot of Selling Per Unit and Cost Per Unit')
